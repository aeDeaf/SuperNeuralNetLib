# %%
import NeuralNet
import numpy
import tensorflow as tf
from math import pi
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_train = numpy.linspace(0, 2 * pi, 30).reshape(1, 30)
y_train = numpy.sin(x_train[0]).reshape(1, 30)

# %%
x_cv = numpy.linspace(0, 2 * pi, 1000).reshape(1, 1000)
y_cv = numpy.sin(x_cv[0]).reshape(1, 1000)

# %%
plt.plot(x_train[0], y_train[0], 'x', color='red')

# %%
net = NeuralNet.NeuralNet(-1, 1, 1)

# %%
net.add_input_layer(1)
net.add(10, tf.sigmoid)

# %%
net.compile()

# %%
cost_list = net.train('prediction', x_train, y_train, 5, 3000, 0.1)
plt.plot(list(map(lambda item: item ** (-1), cost_list)))
# Out:
# 100%|██████████| 3000/3000 [00:01<00:00, 1541.66it/s]

# %%
net.calculate_cost(x_train, y_train)
# Out:
# 0.073770885779221113

# %%
y_pred = net.run(x_cv)
plt.plot(x_train[0], y_train[0], 'x', color='red')
plt.plot(x_cv[0], y_pred[0])

# %%
res = net.unroll_matrixes()

# %%
res[0]
# Out:
# [(array([[-0.95348791],
#          [-0.43653509],
#          [ 0.97585186],
#          [-1.8462971 ],
#          [-0.92089882],
#          [ 2.46685784],
#          [-0.42716889],
#          [-0.68904908],
#          [-1.14848616],
#          [ 0.87866467]]), array([[ 0.85711872],
#          [-0.46756807],
#          [-1.12528987],
#          [-0.03809408],
#          [ 0.60229489],
#          [-2.14070676],
#          [-0.59601025],
#          [-1.04041525],
#          [ 2.14099687],
#          [-0.36908573]])),
#  (array([[ 1.0484938 , -0.11194573, -1.38044409, -1.78519895,  0.99561076,
#            3.12943991, -0.11894323,  0.66416066,  1.49595249, -1.30093554]]),
#   array([[-1.36643626]]))]

# %%
unroll_vector = res[2]

# %%
net.roll_matrixes(unroll_vector)
# Out:
# [(array([[-0.95348791],
#          [-0.43653509],
#          [ 0.97585186],
#          [-1.8462971 ],
#          [-0.92089882],
#          [ 2.46685784],
#          [-0.42716889],
#          [-0.68904908],
#          [-1.14848616],
#          [ 0.87866467]]), array([[ 0.85711872],
#          [-0.46756807],
#          [-1.12528987],
#          [-0.03809408],
#          [ 0.60229489],
#          [-2.14070676],
#          [-0.59601025],
#          [-1.04041525],
#          [ 2.14099687],
#          [-0.36908573]])),
#  (array([[ 1.0484938 , -0.11194573, -1.38044409, -1.78519895,  0.99561076,
#            3.12943991, -0.11894323,  0.66416066,  1.49595249, -1.30093554]]),
#   array([[-1.36643626]]))]
