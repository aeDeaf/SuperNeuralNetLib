# %%
import NeuralNet
import numpy
import tensorflow as tf
from math import pi
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_train = numpy.linspace(0, 2 * pi, 30).reshape(1, 30)
y_train = numpy.sin(x_train[0]).reshape(1, 30)

# %%
x_cv = numpy.linspace(0, 2 * pi, 1000).reshape(1, 1000)
y_cv = numpy.sin(x_cv[0]).reshape(1, 1000)

# %%
plt.plot(x_train[0], y_train[0], 'x', color='red')

# %%
net = NeuralNet.NeuralNet(-10, 10, 1)

# %%
net.add_input_layer(1)
net.add(10, tf.sigmoid)

# %%
net.compile()

# %%
cost_list = net.train('prediction', x_train, y_train, 20, 300000, 0.1)
plt.plot(list(map(lambda item:item ** (-1), cost_list)))
# Out:
# 100%|██████████| 300000/300000 [02:32<00:00, 1963.61it/s]
# [(array([[ 0.81699253],
#        [ 2.81328858],
#        [ 5.88998272],
#        [-8.18235051],
#        [-9.98173238],
#        [-2.61398792],
#        [ 1.05225943],
#        [-3.51738542],
#        [-4.71596835],
#        [ 2.23534356]]), array([[  1.10816718],
#        [-10.76437601],
#        [  9.96917411],
#        [ -4.71516899],
#        [ -9.08251145],
#        [ -5.20364854],
#        [ -6.88761117],
#        [ 13.56150247],
#        [ -7.31740872],
#        [ -5.33060581]])), (array([[ 7.50473032, -4.5619989 ,  5.42448839, -3.36895577,  7.38156147,
#          6.45041272,  3.9094396 , -2.65964556,  5.94156973, -1.62658174]]), array([[-8.42829706]]))]

# %%
net.calculate_cost(x_train, y_train)
# Out:
# 6.5027077751407878e-05

# %%
y_pred = net.run(x_cv)
plt.plot(x_train[0], y_train[0], 'x', color='red')
plt.plot(x_cv[0], y_pred[0])
