# %%
import NeuralNet
import numpy
import tensorflow as tf
from math import pi
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_train = numpy.linspace(0, 2 * pi, 30).reshape(1, 30)
y_train = numpy.sin(x_train[0]).reshape(1, 30)

# %%
x_cv = numpy.linspace(0, 2 * pi, 1000).reshape(1, 1000)
y_cv = numpy.sin(x_cv[0]).reshape(1, 1000)

# %%
plt.plot(x_train[0], y_train[0], 'x', color='red')

# %%
net = NeuralNet.NeuralNet(-1, 1, 1)

# %%
net.add_input_layer(1)
net.add(10, tf.sigmoid)

# %%
net.compile()

# %%
cost_list = net.train('prediction', x_train, y_train, 5, 3000, 0.1)
plt.plot(list(map(lambda item: item ** (-1), cost_list)))
# Out:
# 100%|██████████| 3000/3000 [00:01<00:00, 1869.24it/s]

# %%
net.calculate_cost(x_train, y_train)
# Out:
# 0.044865986336411291

# %%
y_pred = net.run(x_cv)
plt.plot(x_train[0], y_train[0], 'x', color='red')
plt.plot(x_cv[0], y_pred[0])

# %%
res = net.unroll_matrixes()

# %%
res[0]
# Out:
# [(array([[-1.61899466],
#          [ 1.05632672],
#          [-0.24775512],
#          [ 1.94014183],
#          [-0.28072231],
#          [-1.09944884],
#          [ 0.266002  ],
#          [-0.42660716],
#          [-0.96916921],
#          [ 1.5141335 ]]), array([[ 0.00627327],
#          [-0.97101208],
#          [-0.54862469],
#          [-1.78131612],
#          [-0.03001191],
#          [ 1.10759981],
#          [-0.20852977],
#          [-0.93523534],
#          [ 0.07529241],
#          [-3.80906358]])),
#  (array([[-1.83818444, -0.80443359, -0.5224505 ,  2.18284373, -0.55051995,
#            0.71724175,  0.62920948,  0.02609663,  0.71621702, -2.62755369]]),
#   array([[ 0.17044905]]))]

# %%
unroll_vector = res[2]

# %%
net.roll_matrixes(unroll_vector)
# Out:
# [(0, 0), (10, 20), (30, 31)]
# 0 10 20
# 20 30 31
# [(array([[-1.61899466],
#          [ 1.05632672],
#          [-0.24775512],
#          [ 1.94014183],
#          [-0.28072231],
#          [-1.09944884],
#          [ 0.266002  ],
#          [-0.42660716],
#          [-0.96916921],
#          [ 1.5141335 ]]), array([[ 0.00627327],
#          [-0.97101208],
#          [-0.54862469],
#          [-1.78131612],
#          [-0.03001191],
#          [ 1.10759981],
#          [-0.20852977],
#          [-0.93523534],
#          [ 0.07529241],
#          [-3.80906358]])),
#  (array([[-1.83818444, -0.80443359, -0.5224505 ,  2.18284373, -0.55051995,
#            0.71724175,  0.62920948,  0.02609663,  0.71621702, -2.62755369]]),
#   array([[ 0.17044905]]))]
