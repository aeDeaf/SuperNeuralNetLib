# %%
import NeuralNet
import numpy
import tensorflow as tf
from math import pi
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_train = numpy.linspace(0, 2 * pi, 30).reshape(1, 30)
y_train = numpy.sin(x_train[0]).reshape(1, 30)

# %%
x_cv = numpy.linspace(0, 2 * pi, 1000).reshape(1, 1000)
y_cv = numpy.sin(x_cv[0]).reshape(1, 1000)

# %%
plt.plot(x_train[0], y_train[0], 'x', color='red')

# %%
net = NeuralNet.NeuralNet(-1, 1, 1)

# %%
net.add_input_layer(1)
net.add(10, tf.sigmoid)

# %%
net.compile()

# %%
cost_list = net.train('prediction', x_train, y_train, 5, 3000, 0.1)
plt.plot(list(map(lambda item: item ** (-1), cost_list)))
# Out:
# 100%|██████████| 3000/3000 [00:01<00:00, 1872.69it/s]

# %%
net.calculate_cost(x_train, y_train)
# Out:
# 0.048658301194863855

# %%
y_pred = net.run(x_cv)
plt.plot(x_train[0], y_train[0], 'x', color='red')
plt.plot(x_cv[0], y_pred[0])

# %%
res = net.unroll_matrixes()

# %%
res[0]
# Out:
# [(array([[-0.23575201],
#          [-0.33310027],
#          [-0.78474983],
#          [ 2.12522037],
#          [-1.58490852],
#          [ 0.68065007],
#          [-0.72262996],
#          [-0.23851662],
#          [ 1.06134236],
#          [-0.25096718]]), array([[-0.82503614],
#          [ 0.48967492],
#          [ 0.86080416],
#          [-1.5804787 ],
#          [ 3.91886149],
#          [ 1.09532905],
#          [ 0.74693038],
#          [-0.91490023],
#          [-0.94766607],
#          [-0.60121502]])),
#  (array([[-0.33259388, -0.54285313, -0.00358617,  2.61901047,  2.48996084,
#           -0.91552904, -0.05011489, -0.26981493, -0.98370644, -0.54636196]]),
#   array([[-1.19926906]]))]

# %%
unroll_vector = res[2]
# Out:
# array([ -2.35752014e-01,  -3.33100274e-01,  -7.84749827e-01,
#          2.12522037e+00,  -1.58490852e+00,   6.80650066e-01,
#         -7.22629956e-01,  -2.38516620e-01,   1.06134236e+00,
#         -2.50967182e-01,  -8.25036139e-01,   4.89674917e-01,
#          8.60804156e-01,  -1.58047870e+00,   3.91886149e+00,
#          1.09532905e+00,   7.46930380e-01,  -9.14900233e-01,
#         -9.47666072e-01,  -6.01215020e-01,  -3.32593882e-01,
#         -5.42853132e-01,  -3.58617046e-03,   2.61901047e+00,
#          2.48996084e+00,  -9.15529036e-01,  -5.01148923e-02,
#         -2.69814927e-01,  -9.83706441e-01,  -5.46361956e-01,
#         -1.19926906e+00])

# %%
net.roll_matrixes(unroll_vector)
